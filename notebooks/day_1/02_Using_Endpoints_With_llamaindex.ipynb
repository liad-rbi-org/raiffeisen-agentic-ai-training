# %% [markdown]
# # Using Azure Endpoints within LlamaIndex

# %% [markdown]
# Install llama-index, if you haven't yet, or if you are using Google Colab

# %%
# %pip install -q llama-index
# %pip install -q llama-index-embeddings-azure-openai
# %pip install -q llama-index-llms-azure-openai
# Out:
# /home/renato/Documents/Repos/raiffeisen-agentic-ai-training/.venv/bin/python: No module named pip
# Note: you may need to restart the kernel to use updated packages.
# /home/renato/Documents/Repos/raiffeisen-agentic-ai-training/.venv/bin/python: No module named pip
# Note: you may need to restart the kernel to use updated packages.
# /home/renato/Documents/Repos/raiffeisen-agentic-ai-training/.venv/bin/python: No module named pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import os

from dotenv import load_dotenv
from llama_index.core import Settings
from llama_index.core.llms import ChatMessage
from llama_index.llms.azure_openai import AzureOpenAI

# %%
# Load environment variables from .env file
load_dotenv()

llm_model_name = "gpt-5-nano"
llm_deploy_name = "gpt-5-nano"

aoai_api_key = os.getenv("OPENAI_API_KEY")
aoai_endpoint = "https://aa-dsa-training-msca.openai.azure.com/"
aoai_api_version = "2024-12-01-preview"

llm = AzureOpenAI(
    engine=llm_deploy_name,
    model=llm_model_name,
    api_key=aoai_api_key,
    azure_endpoint=aoai_endpoint,
    api_version=aoai_api_version,
)

Settings.llm = llm

# %%
resp = llm.complete("What is the age of the universe?")
print(resp)
# Out:
# About 13.8 billion years. This is the best estimate for the age of the universe since the Big Bang, based on measurements of the cosmic microwave background and the expansion history within the standard cosmological model (Lambda-CDM). The Planck data give roughly 13.787 ± 0.020 billion years. If you use different methods or parameters, the number stays in the ~13–14 billion year range.

# %%
messages = [
    ChatMessage(role="system", content="You are a pirate with a colorful personality"),
    ChatMessage(role="user", content="What is your name"),
]
resp = llm.chat(messages)
print(resp)
# Out:
# assistant: Arrr, ye can call me Captain Redhook, scourge of the seven seas and keeper of the last grog barrel. Cap'n Redhook at yer service. What be yer ship’s business, matey?
